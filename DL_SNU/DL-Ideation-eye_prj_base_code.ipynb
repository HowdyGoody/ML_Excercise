# %%
#================================
# Get max "countinuous 0" from 1-d array
#================================

def getMaxLength(arr, n):
 
    # initialize count
    count = 0
     
    # initialize max
    result = 0
 
    for i in range(0, n):
     
        # Reset count when 0 is found
        if (arr[i] == 0):
            count = 0
 
        # If 1 is found, increment count
        # and update result if count
        # becomes more.
        else:
             
            # increase count
            count+= 1
            result = max(result, count)
         
    return result
 
# Driver code
arr = [1, 1, 0, 0, 1, 0, 1,
             0, 1, 1, 1, 1]
n = len(arr)
 
print(getMaxLength(arr, n))
#================================


#================================
# Get eye width and height from a CSV
#================================

def update_xy (df) :
    df['max_h'] = 0
    df['max_w'] = 0

    array_eye_csv_for_org = df.to_numpy()
    array_eye_csv_for_trans = np.transpose(array_eye_csv_for_row)
    num_rows = array_eye_csv_for_org.shape[0]
    num_cols = array_eye_csv_for_org.shape[1]

    max_width = 0
    for i in range(0, num_rows) : 
        max_len = getMaxLength(array_eye_csv_for_org[i], num_cols)
        if (max_len > max_width) :  max_width =  max_len 

    max_height = 0
    for i in range(0, num_cols) : 
        max_len = getMaxLength(array_eye_csv_for_trans[i], num_rows)
        if (max_len > max_height) :  max_height =  max_len 

    return x, y
#================================



def csv_to_img(csv) :
    for i in range(0, ) : 
    return img

#================================
# Main function
#================================
import os


list_csv = glob.glob("/home/adam/*/*.csv")) 
count = len(list_csv)

for idx, name in enumerate(list_csv) :
    eye_info = np.zeros((count,4))
    df = pd.read_csv(filename, sep=',', header=None)
    eye_xy[csv_id][0] = idx
    eye_xy[csv_id][1] = (df*255).to_numpy  # image 
    eye_xy[csv_id][2], eye_xy[csv_id][3] = update_xy(df)
    eye_xy[csv_id][4] = 1 if(eye_xy[csv_id][2] > criterion_x) and (eye_xy[csv_id][3] > criterion_y)
