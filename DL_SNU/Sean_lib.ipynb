# %% [markdown]
# # Print Basic Information of NUMPY / DATAFRAME / ETC

# %%
import numpy as np
import pandas as pd

# print np or df information
def print_data_info(data, msg="") :
    if( type(data) == type ( np.empty([2, 2]) ) ) :

        print("\n============================")
        print(msg)
        print("============================")
        print("Type : ",  type(data))
        print("Shape : ", data.shape)
        print("Unique : ", np.unique(data, return_counts=True))
        print("Data : ", data)
        print("============================\n")
    elif ( type(data) == type(pd.DataFrame([1])) ) :
        print("\n============================")
        print(msg)
        print("============================")
        print(type(data))
        print("Unique : ", np.unique(np.array(data), return_counts=True))
        print(data.info())
        print(data.head())
        print("============================\n")
    else :
        print("\n============================")
        print(msg)
        print("============================")
        print(type(data))
        print("Data : ", data)
        print("============================\n")

# %% [markdown]
# # DataFrame Feature Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from scipy import stats
from statsmodels.datasets import get_rdataset
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.stattools import adfuller, kpss


df = pd.read_csv('https://raw.githubusercontent.com/JWarmenhoven/ISLR-python/master/Notebooks/Data/Advertising.csv', usecols=[1,2,3,4])


# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def boxplot(df, col):
    sns.boxplot(data=df,x=df[f"{col}"])
    plt.title(f"Feature {col}")
    plt.show()

def show_df_info(data, x, hue=None):
    fig, axes = plt.subplots(1,2, figsize=(10, 5))
    # fig.suptitle('Features')
    #sns.histplot(data=penguins, x="flipper_length_mm", kde=True)
    #sns.histplot(x=x, data=data, kde=True, hue=hue)

    sns.histplot(ax=axes[0], data=data, x=x, kde=True) #, hue=hue)    
    sns.boxplot(ax=axes[1], data=data[x])
    plt.show()


def print_df_info(df) :
    print("====================================================================")
    print("=           DataFrame Information                                  =")
    print("====================================================================")
    print(df.info())

    print("====================================================================")
    display(df.head(3))
    print("====================================================================")
    print()


    print("====================================================================")
    print("[Columns]\t", df.columns)
    print("====================================================================")
    print()

    print("====================================================================")
    print("[INDICES]\t",df.index)
    print("====================================================================")

    print()
    print("====================================================================")
    print("=           DataFrame Description                                  =")
    print("====================================================================")

    print(df.describe())
    print("====================================================================")



    for col in df.columns :
        print("====================================================================")
        print("[ " +  col + " ]")
        print("====================================================================")
        show_df_info(df, col)

        print(col + "   Unique : ", df[col].unique())
        print("--------------------------------------------------------------------")
        print(col + "   N unique : ", df[col].nunique())
        print("--------------------------------------------------------------------")
        print(col + "   Value Counts : ", df[col].value_counts())
        print("--------------------------------------------------------------------")
        print()
        print()
        print()

        
    sns.pairplot(df)
    plt.show()

    plt.figure(figsize=(15, 10))
    sns.heatmap(df, cmap=sns.cubehelix_palette(as_cmap=True))
    plt.show()


print_df_info(df)
# Out:
# ...
# =           DataFrame Information                                  =
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB
# None
# ...
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# ...
#
# ...
# [Columns]	 Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')
# ...
#
# ...
# [INDICES]	 RangeIndex(start=0, stop=200, step=1)
# ...
#
# ...
# =           DataFrame Description                                  =
# ...
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# ...

# %% [markdown]
# # CSV to IMG

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import sklearn.metrics as metrics
from sklearn.metrics import fbeta_score, classification_report,confusion_matrix
import os
import tensorflow as tf
from PIL import Image 

import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
import random
import shutil


dir_path = 'c:/KJH/challenge2/data/'
dir_path_csv = 'c:/KJH/challenge2/data/20220926_T4_burstmode_VT_sweep_eom/'
dir_path_image = 'c:/KJH/challenge2/data/i_20220926_T4_burstmode_VT_sweep_eom'
dir_path_result = 'c:/KJH/challenge2/data/r_20220926_T4_burstmode_VT_sweep_eom'
#------------------------------------------------------------------------------------------------------------------------
#convert csv data to image

file_list = os.listdir(dir_path_csv)
file_list_csv = [file for file in file_list if file.endswith(".csv")]
print ("file_list_py: {}".format(file_list_csv))
for i in file_list_csv:
    df = pd.read_csv(dir_path_csv+i,index_col = 0)
    tf_data = np.array(df)
    tf_data = np.round((tf_data/64)*255)
    tf_data = tf_data.astype(int)
    im = Image.fromarray(tf_data)
    im =im.convert('L')
    im.save(dir_path_image+'/'+i.split('.')[0]+'.png','PNG')

#------------------------------------------------------------------------------------------------------------------------
#image <-> csv Label matching,  folder classification
from openpyxl.utils.cell import coordinate_from_string
import openpyxl
filename = dir_path+'eye_info_2022-11-22-1237.xlsx'
book = openpyxl.load_workbook(filename)
sheet = book.worksheets[0]
imagefile_list = os.listdir(dir_path_image)
imagefile_list[0]

for image in imagefile_list:
    for i in range(1,sheet.max_row):
        if sheet.cell(row=i, column=3).value +'.png' == image:
            print(image,sheet.cell(row=i, column=6).value)
            shutil.copy(dir_path_image+'/'+image, dir_path_result+'/'+str(sheet.cell(row=i, column=6).value)+'/'+image)

#-----------------------------------------------------------------------------------------------------------------------
#data flip
import cv2
import matplotlib.pyplot as plt

for i in file_list:
   img_= cv2.imread(path+'/1/'+i)
   img_flip = cv2.flip(img_, 1)
   cv2.imwrite(path_aug+'/1/_'+i,img_flip)

#-----------------------------------------------------------------------------------------------------------------------
# folder Image data load 
'''
path = dir_path+'r_20220922_eom_data_index_fix'
img_height =128
img_width =128 
batch_size = 16
train_ds = tf.keras.utils.image_dataset_from_directory(
    path,
    validation_split=0.2,
    subset="training",
    seed=123,
    color_mode = 'grayscale',
    image_size=(img_height, img_width),
    batch_size=batch_size)

test_ds = tf.keras.utils.image_dataset_from_directory(
  path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  color_mode = 'grayscale',
  image_size=(img_height, img_width),
  batch_size=batch_size)
'''

#-----------------------------------------------------------------------------------------------------------------------
#image rgb to gray
dir_path_img = 'c:/KJH/challenge2/data/create_data/'
file_list = os.listdir(dir_path_img+'/1')
file_list_img = [file for file in file_list if file.endswith(".png")]
for imagePath in file_list_img:
    img = Image.open(dir_path_img+'/1/'+imagePath).convert('L')
    img_numpy = np.array(img, 'uint8')
    cv2.imwrite(dir_path_img + '/1_/'+imagePath, img_numpy)

# %% [markdown]
# # Show Iterative Operation Progress

# %%
# !pip install pqdm
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\SNUAI\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from tqdm import tqdm, trange
import time

for i in tqdm(range(100), desc="Test1") :
    time.sleep(0.001)
    
for i in tqdm(range(100), desc="Test2") :
    time.sleep(0.001)
# Out:
# ...
# Test2: 100%|██████████| 100/100 [00:01<00:00, 63.59it/s]

# %%
print("done")
# Out:
# done
