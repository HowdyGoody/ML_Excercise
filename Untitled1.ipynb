# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')


# In[2]:

# %%
np.random.seed(1)
X = np.random.rand(40, 1) ** 2
y = (10 - 1. / (X.ravel() + 0.1)) + np.random.randn(40)


# In[3]:


from sklearn.model_selection import validation_curve


# In[4]:


degree = np.arange(0, 21)


# In[6]:


train_score, val_score = validation_curve(make_pipeline(PolynomialFeatures(degree=2), \
                                                        LinearRegression()), \
                                          X, y, "polynomialfeatures__degree", degree, cv=7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 21>()
#      15 degree = np.arange(0, 21)
#      18 # In[6]:
# ---> 21 train_score, val_score = validation_curve(make_pipeline(PolynomialFeatures(degree=2), \
#      22                                                         LinearRegression()), \
#      23                                           X, y, "polynomialfeatures__degree", degree, cv=7)
#
# TypeError: validation_curve() takes 3 positional arguments but 5 positional arguments (and 1 keyword-only argument) were given

# %%
# In[13]:


plt.figure(figsize=(8, 5))
plt.plot(degree, np.median(train_score, 1), "b-", label="training score")
plt.plot(degree, np.median(val_score, 1), "r-", label="validation score")
plt.ylim(0, 1)
plt.xlabel("degree")
plt.ylabel("score")
plt.legend(loc="best");


# In[16]:


X_test = np.linspace(-0.1, 1.1, 500).reshape(-1, 1)


# In[19]:


plt.figure(figsize=(8, 7))
plt.scatter(X.ravel(), y)
lim = plt.axis()
y_pred = make_pipeline(PolynomialFeatures(degree=3), LinearRegression()).fit(X, y).predict(X_test)
plt.plot(X_test.ravel(), y_pred)
plt.axis(lim);


# In[20]:


from sklearn.model_selection import learning_curve


# In[25]:


fig, ax = plt.subplots(1, 2, figsize=(16, 6))
for i, degree in enumerate([2, 9]):
    n, train_lc, val_lc = learning_curve(make_pipeline(PolynomialFeatures(degree=degree),                                                        LinearRegression()),                                          X, y, cv=7, train_sizes=np.linspace(0.1, 1, 25))
    ax[i].plot(n, np.mean(train_lc, 1), "b-", label="training score")
    ax[i].plot(n, np.mean(val_lc, 1), "r-", label="validation score")
    ax[i].hlines(np.mean([train_lc[-1], val_lc[-1]]), n[0], n[-1], color="gray", linestyle="dashed")
    ax[i].set(xlim=(n[0], n[-1]), ylim=(0, 1), xlabel="training size", ylabel="score")
    ax[i].set_title("degree = {}".format(degree), size=14)
    ax[i].legend(loc="best");


# In[26]:


from sklearn.model_selection import GridSearchCV


# In[27]:


params = {"polynomialfeatures__degree": np.arange(21),
          "linearregression__fit_intercept": [True, False],
          "linearregression__normalize": [True, False]}


# In[30]:


grid = GridSearchCV(make_pipeline(PolynomialFeatures(),                                   LinearRegression()), params, iid=True, cv=7)


# In[31]:


grid.fit(X, y)


# In[32]:


grid.best_params_


# In[33]:


model = grid.best_estimator_
model


# In[36]:


plt.figure(figsize=(8, 7))
plt.scatter(X.ravel(), y)
lim = plt.axis()
y_pred = model.fit(X, y).predict(X_test)
plt.plot(X_test.ravel(), y_pred)
plt.axis(lim);


# In[ ]:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 38>()
#      32 degree = np.arange(0, 21)
#      35 # In[6]:
# ---> 38 train_score, val_score = validation_curve(make_pipeline(PolynomialFeatures(degree=2),                                                         LinearRegression()),                                           X, y, "polynomialfeatures__degree", degree, cv=7)
#      41 # In[13]:
#      44 plt.figure(figsize=(8, 5))
#
# TypeError: validation_curve() takes 3 positional arguments but 5 positional arguments (and 1 keyword-only argument) were given
